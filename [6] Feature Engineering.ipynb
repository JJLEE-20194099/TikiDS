# %%
import pandas as pd
import numpy as np

# %%
detail_df = pd.read_csv('./data/crawl_data/categories/thuc-pham-tuoi-song/item_detail.csv', sep=',', encoding='utf-8')
detail_df.head(5)
# Out:
#           id                                               name  \
# 0  100424496   [Chỉ Giao HCM] - Sầu Riêng Ri 6 Nguyên Múi 500gr
# 1  109910895  NutiMilk Đẹp - Thùng 48 Hộp Sữa chua Tổ Yến TU...
# 2  125818914  [Chỉ Giao HCM] Chuối Laba Lâm Đồng Trợ Giá Tận...
# 3  109915267  NutiMilk Thùng 48 Hộp Sữa chua Trân Châu Đường...
# 4  120789636  [FARMVILL] [Chỉ Giao HCM] Combo 2 Trái Bưởi Da...
#
#                                         category     brand   price  discount  \
# 0  Thực Phẩm Tươi Sống/Trái Cây/Trái Cây Nội Địa       OEM  159000         0
# 1    TIKINGON/Sữa, bơ, phô mai/Sữa chua, phô mai  NutiFood  480000         0
# 2  Thực Phẩm Tươi Sống/Trái Cây/Trái Cây Nội Địa       OEM   21000     18000
# 3    TIKINGON/Sữa, bơ, phô mai/Sữa chua, phô mai  NutiFood  480000         0
# 4  Thực Phẩm Tươi Sống/Trái Cây/Trái Cây Nội Địa       OEM   95000         0
#
#    discount_rate                                               mota  \
# ...
